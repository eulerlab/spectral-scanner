# %%
# import seabreeze (use 'pyseabreeze')
import seabreeze.spectrometers as sb

import os
import math
import numpy as np
import matplotlib.pyplot as plt
import time
import datetime

# set graphics to be plotted in the notebook
# %matplotlib inline 

devices = sb.list_devices()
print (devices)
# Out:
# [<SeaBreezeDevice STS:S03615>]

# %%
# !pip install seabreeze
import seabreeze.spectrometers as sb
# Out:
# Requirement already satisfied: seabreeze in /Users/eulerlab/miniconda3/lib/python3.11/site-packages (2.10.1)
# Requirement already satisfied: numpy>=1.21 in /Users/eulerlab/miniconda3/lib/python3.11/site-packages (from seabreeze) (2.2.6)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 get_ipython().system('pip install seabreeze')
# ----> 2 import seabreeze.spectrometers as sb
#
# ModuleNotFoundError: No module named 'seabreeze'

# %%
import sys
print(sys.executable)
print(sys.path)
# Out:
# /usr/local/bin/python3
# ['/Users/eulerlab/Desktop', '/Library/Frameworks/Python.framework/Versions/3.10/lib/python310.zip', '/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10', '/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/lib-dynload', '', '/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages', '/Users/eulerlab/Github/ama_util', '/Users/eulerlab/Github/c2s', '/Users/eulerlab/Github/stimgenerator']

# %%
# Install seabreeze into current environment
import sys
# !{sys.executable} -m pip install seabreeze
# Out:
# Collecting seabreeze
#   Downloading seabreeze-2.10.1-cp310-cp310-macosx_10_9_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.21 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from seabreeze) (1.24.2)
# Downloading seabreeze-2.10.1-cp310-cp310-macosx_10_9_x86_64.whl (887 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.1/887.1 kB 5.3 MB/s eta 0:00:0000:0100:01
# Installing collected packages: seabreeze
# Successfully installed seabreeze-2.10.1
#
# [notice] A new release of pip is available: 23.3.1 -> 25.1.1
# [notice] To update, run: pip3.10 install --upgrade pip
